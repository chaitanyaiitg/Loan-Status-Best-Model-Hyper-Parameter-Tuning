# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('F:\Data_Science\Loan Status\loan-train.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender']=df['Gender'].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Married']=df['Married'].replace({np.nan:'No'})

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Dependents']=df['Dependents'].replace({'3+':3})

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Dependents']=df.groupby(['Married'])['Dependents'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', 3], dtype=object)

# %%
df['Dependents']=df['Dependents'].astype(int)

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents             int32
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df['Self_Employed']=df['Self_Employed'].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mode()[0])
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df['Credit_History']=df.groupby(['Loan_Status'])['Credit_History'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(1), int64(1), object(7)
# memory usage: 60.1+ KB

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    525
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df.drop(['Loan_ID'],axis=1,inplace=True)

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No           0      Graduate            No             5849
# 1      Male     Yes           1      Graduate            No             4583
# 2      Male     Yes           0      Graduate           Yes             3000
# 3      Male     Yes           0  Not Graduate            No             2583
# 4      Male      No           0      Graduate            No             6000
# ..      ...     ...         ...           ...           ...              ...
# 609  Female      No           0      Graduate            No             2900
# 610    Male     Yes           3      Graduate            No             4106
# 611    Male     Yes           1      Graduate            No             8072
# 612    Male     Yes           2      Graduate            No             7583
# 613  Female      No           0      Graduate           Yes             4583
#
# ...

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
plt.figure(figsize = (16,14))
plt.subplot(3,2,1)
sns.countplot(x='Gender',data=df)

plt.subplot(3,2,2)
sns.countplot(x='Married',data=df)

plt.subplot(3,2,3)
sns.countplot(x='Gender',hue='Loan_Status',data=df)

plt.subplot(3,2,4)
sns.countplot(x='Married',hue='Loan_Status',data=df)

plt.subplot(3,2,5)
sns.countplot(x='Education',data=df)

plt.subplot(3,2,6)
sns.countplot(x='Education',hue='Loan_Status',data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(y='ApplicantIncome',x='LoanAmount',hue='Loan_Status', data=df)

# %%
plt.figure(figsize = (15,6))
plt.subplot(1,3,1)
sns.countplot(x='Gender', hue='Property_Area', data=df)

plt.subplot(1,3,2)
sns.countplot(x='Married', hue='Property_Area', data=df)

plt.subplot(1,3,3)
sns.countplot(x='Property_Area', hue='Loan_Status', data=df)

# %%
plt.figure(figsize=(10,6))

sns.catplot(x='Property_Area',y='LoanAmount',hue='Loan_Status', data=df,kind='boxen',col='Gender',palette='Set2')

sns.catplot(x='Property_Area',y='LoanAmount',hue='Loan_Status', data=df,kind='boxen',col='Married',palette='Set1')

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Gender']=encoder.fit_transform(df['Gender'])
df['Married']=encoder.fit_transform(df['Married'])
df['Education']=encoder.fit_transform(df['Education'])
df['Self_Employed']=encoder.fit_transform(df['Self_Employed'])
df['Property_Area']=encoder.fit_transform(df['Property_Area'])

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
df.dtypes
# Out:
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status           object
# dtype: object

# %%
df1=pd.read_csv('F:\Data_Science\Loan Status\loan-test.csv')

# %%
df1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df1['Gender']=df1['Gender'].fillna(method='ffill')

# %%
df1['Dependents']=df1.groupby(['Married'])['Dependents'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df1['Self_Employed']=df1['Self_Employed'].fillna(method='ffill')

# %%
df1['LoanAmount']=df1['LoanAmount'].fillna(df1['LoanAmount'].mode()[0])
df1['Loan_Amount_Term']=df1['Loan_Amount_Term'].fillna(df1['Loan_Amount_Term'].mode()[0])

# %%
df1['Credit_History']=df1['Credit_History'].fillna(method='ffill')

# %%
df1.drop(['Loan_ID'],axis=1,inplace=True)

# %%
df1['Dependents']=df1['Dependents'].replace({'3+':3})

# %%
df1['Dependents']=df1['Dependents'].astype(int)

# %%
df1
# Out:
#     Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes           0      Graduate            No             5720
# 1     Male     Yes           1      Graduate            No             3076
# 2     Male     Yes           2      Graduate            No             5000
# 3     Male     Yes           2      Graduate            No             2340
# 4     Male      No           0  Not Graduate            No             3276
# ..     ...     ...         ...           ...           ...              ...
# 362   Male     Yes           3  Not Graduate           Yes             4009
# 363   Male     Yes           0      Graduate            No             4158
# 364   Male      No           0      Graduate            No             3250
# 365   Male     Yes           0      Graduate            No             5000
# 366   Male      No           0      Graduate           Yes             9200
#
# ...

# %%
df1.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int32
#  1   Married            614 non-null    int32
#  2   Dependents         614 non-null    int32
#  3   Education          614 non-null    int32
#  4   Self_Employed      614 non-null    int32
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int32
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(6), int64(1), object(1)
# memory usage: 43.3+ KB

# %%
df1['Gender']=encoder.fit_transform(df1['Gender'])
df1['Married']=encoder.fit_transform(df1['Married'])
df1['Education']=encoder.fit_transform(df1['Education'])
df1['Self_Employed']=encoder.fit_transform(df1['Self_Employed'])
df1['Property_Area']=encoder.fit_transform(df1['Property_Area'])

# %%
df1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1           0          0              0             5720
# 1         1        1           1          0              0             3076
# 2         1        1           2          0              0             5000
# 3         1        1           2          0              0             2340
# 4         1        0           0          1              0             3276
# ..      ...      ...         ...        ...            ...              ...
# 362       1        1           3          1              1             4009
# 363       1        1           0          0              0             4158
# 364       1        0           0          0              0             3250
# 365       1        1           0          0              0             5000
# 366       1        0           0          0              1             9200
#
# ...

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int32
#  1   Married            614 non-null    int32
#  2   Dependents         614 non-null    int32
#  3   Education          614 non-null    int32
#  4   Self_Employed      614 non-null    int32
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int32
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(6), int64(1), object(1)
# memory usage: 43.3+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             367 non-null    int32
#  1   Married            367 non-null    int32
#  2   Dependents         367 non-null    int32
#  3   Education          367 non-null    int32
#  4   Self_Employed      367 non-null    int32
#  5   ApplicantIncome    367 non-null    int64
#  6   CoapplicantIncome  367 non-null    int64
#  7   LoanAmount         367 non-null    float64
#  8   Loan_Amount_Term   367 non-null    float64
#  9   Credit_History     367 non-null    float64
#  10  Property_Area      367 non-null    int32
# dtypes: float64(3), int32(6), int64(2)
# memory usage: 23.1 KB

# %%
X_train=df.iloc[:,:-1]

# %%
X_train.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
y_train=df.iloc[:,-1]

# %%
y_train
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
X_test=df1

# %%
X_test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1           0          0              0             5720
# 1         1        1           1          0              0             3076
# 2         1        1           2          0              0             5000
# 3         1        1           2          0              0             2340
# 4         1        0           0          1              0             3276
# ..      ...      ...         ...        ...            ...              ...
# 362       1        1           3          1              1             4009
# 363       1        1           0          0              0             4158
# 364       1        0           0          0              0             3250
# 365       1        1           0          0              0             5000
# 366       1        0           0          0              1             9200
#
# ...

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df.corr(), annot = True, cmap = "RdYlGn")
plt.show()

# %%
# find and remove correlated features
def correlation(dataset, threshold):
    col_corr = list()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.append(colname)
    return col_corr

correlation(df, 0.6)
# Out:
# []

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesClassifier
selection = ExtraTreesClassifier()
selection.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
print(selection.feature_importances_)
# Out:
# [0.02115201 0.02011126 0.0572054  0.01693652 0.02001831 0.18840925
#  0.11881514 0.18153527 0.04707215 0.27989078 0.04885392]

# %%
plt.figure(figsize=(15,10))
feature_imp=pd.Series(selection.feature_importances_, index=X_train.columns)
feature_imp.nlargest(14).plot(kind='barh')

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
value=[]
algo=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=.3, random_state=42)
    cv_score=cross_val_score(model,X_train,y_train,cv=cv).mean()
    print('CV_Score' + ' '+ str(model) +': '+ str(cv_score))
    value.append(cv_score)
    algo.append(name)

cross_val_score_model(SVC(),'SVC')
cross_val_score_model(RandomForestClassifier(),'Random Forest Classifier')
cross_val_score_model(XGBClassifier(),'XGB Classifier')
cross_val_score_model(KNeighborsClassifier(),'KNeighbors Classifier')
cross_val_score_model(DecisionTreeClassifier(),'DecisionTree Classifier')
cross_val_score_model(LogisticRegression(solver='liblinear',multi_class='auto'),'Logistic Regression')
# Out:
# CV_Score SVC(): 0.6724324324324324
# CV_Score RandomForestClassifier(): 0.7870270270270271
# CV_Score XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None): 0.7675675675675675
# CV_Score KNeighborsClassifier(): 0.6172972972972972
# CV_Score DecisionTreeClassifier(): 0.6940540540540541
# CV_Score LogisticRegression(solver='liblinear'): 0.8032432432432433

# %%
model_params={
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[100,200,500,1000],
            'criterion' : ['gini', 'entropy'],
            'max_features' : ['auto', 'sqrt'],
            'max_depth' : [5,10,15,20,25,30,35,40,45,50,70,100]
        }
    },
        'XGBoost':{
        'model':XGBClassifier(),
        'params':{
            'booster':['gbtree','gblinear'],
            'learning_rate':[0.05,0.1,0.15,0.20],
            'max_depth' : [5,10,15,20,25,30,35,40,45,50,75,100]
        }
    },

        'LogisticRegression':{
        'model':LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'penalty' : ['l1','l2','elasticnet'],
            'C':[1,10,50,100,200]
        }
    }
}

# %%
scores=[]
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=42)
for model_name, mp in model_params.items():
    random_clf=RandomizedSearchCV(mp['model'],mp['params'],cv=cv, return_train_score=False)
    random_clf.fit(X_train,y_train)
    scores.append({
        'model':model_name,
        'best_score':random_clf.best_score_,
        'best param':random_clf.best_params_,
        'best estimator':random_clf.best_estimator_
    })

ds=pd.DataFrame(scores,columns=['model','best_score','best param','best estimator'])
ds
# Out:
# [20:58:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [20:58:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [20:58:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_depth } might not be used.
#
# ...

# %%
def display_text_max_col_width(df, width):
    with pd.option_context('display.max_colwidth', width):
        print(df)

display_text_max_col_width(ds['best param'], 800)
# Out:
# 0    {'n_estimators': 100, 'max_features': 'auto', 'max_depth': 5, 'criterion': 'entropy'}
# 1                          {'max_depth': 45, 'learning_rate': 0.05, 'booster': 'gblinear'}
# 2                                                                {'penalty': 'l1', 'C': 1}
# Name: best param, dtype: object

# %%
cross_val_score_model(RandomForestClassifier(n_estimators=100,criterion='entropy',max_features='auto', max_depth=5),'Random Forest Classifier_Best')
cross_val_score_model(XGBClassifier(max_depth=45,learning_rate= 0.05, booster='gblinear'),'XGB Classifier_Best')
cross_val_score_model(LogisticRegression(solver='liblinear',multi_class='auto',penalty='l1',C=11),'Logistic Regression_best')
# Out:
# CV_Score RandomForestClassifier(criterion='entropy', max_depth=5): 0.801081081081081
# [21:00:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:00:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:00:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# ...

# %%
sns.barplot(x=value,y=algo)
plt.xlabel('Cross_Val_Score')
plt.ylabel('Model')
plt.show()

# %%
Best1=pd.Series(algo)
Best2=pd.Series(value)
pd.DataFrame({'Model':Best1,'CVScore':Best2})
# Out:
#                            Model   CVScore
# 0                            SVC  0.672432
# 1       Random Forest Classifier  0.787027
# 2                 XGB Classifier  0.767568
# 3          KNeighbors Classifier  0.617297
# 4        DecisionTree Classifier  0.694054
# 5            Logistic Regression  0.803243
# 6  Random Forest Classifier_Best  0.801081
# 7            XGB Classifier_Best  0.805405
# 8       Logistic Regression_best  0.804324

# %%
#BEST MODEL : XGBoost MODEL' WITH HYPER PARAMETER TUNING

# %%
from sklearn.metrics import accuracy_score
xgb=XGBClassifier(max_depth=45,learning_rate= 0.05, booster='gblinear')
xgb.fit(X_train,y_train)
xgb_y_pred=xgb.predict(X_test)
data_best=pd.DataFrame(xgb_y_pred)
data_best.columns=['Loan Status']
data_best.head(50)
# Out:
# [21:17:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_depth } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#    Loan Status
# 0            Y
# 1            Y
# 2            Y
# 3            Y
# 4            Y
# 5            Y
# 6            Y
# 7            N
# 8            Y
# 9            Y
# 10           Y
# 11           Y
# 12           Y
# 13           N
# 14           Y
# 15           Y
# 16           Y
# 17           Y
# 18           Y
# 19           Y
# 20           Y
# 21           Y
# 22           Y
# 23           Y
# 24           Y
# 25           N
# 26           N
# 27           Y
# 28           Y
# 29           Y
# 30           Y
# 31           Y
# 32           Y
# 33           Y
# ...

# %%
data_best['Loan Status'].value_counts()
# Out:
# Y    306
# N     61
# Name: Loan Status, dtype: int64
